# %% [markdown]
# <a href="https://colab.research.google.com/github/Anne-va/Linear-Algebra-58051/blob/main/Week%204/LinAlg_Lab4_58051_Ebdane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math 

N = np.array ([1, 8, -9, 9])
I = np.array ([5, 2, 4, -10])
M = np.array ([-3, 7, 6, -3])
F = np.array ([1, 8, -8, 11])
A = np.array ([12, 7,-3, -14])
S = np.array ([11, 5, -2, 7])

R_S = math.sqrt(sum(S**2))
R_S
# Out:
# 14.106735979665885

# %%
import numpy as np

P = np.array ([1, -8, 7, 9, 10])
R = np.array ([7, -2, 11, 8, 9])
E = np.array ([-9, -18, 8, 1, -2])
C = np.array ([17, -8, 9, 2, -10])
I = np.array ([2, -3, 9, 1, 5])
O = np.array ([5, 15, 6, 3, 2])
U = np.array ([6, 10, 8, 12, -6])
S = np.array ([3, 9, 12, -14, 9])
A = np.array ([-14, 5, 3, 8, 12])
N = np.array ([9, 12, -4, -6, -1])

# %%
Z1 = sum(P*R)
Z2 = sum(E*C)
Z3 = sum(I*O)
Z4 = sum(U*S)
Z5 = sum(A*N)

print(Z1)
print(Z2)
print(Z3)
print(Z4)
print(Z5)
# Out:
# 262
# 85
# 32
# -18
# -138

# %%
A = np.array([-0.4,0.3,-0.6])
B = np.array([-0.2,0.2,1])
C = np.array([-0.2,0.1,-1.5])

Result = ((A**2) + (B**2) + (C**2)) * (A * (B + (A *B))/C) * abs(A + B + C)
Result
# Out:
# array([-0.04608,  0.06552,  0.63536])

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.gca(projection='3d')
plt.quiver(0,0,0, total[0], total[1], total[2], colors = 'r')
ax1.set_xlim([-300,400])
ax1.set_ylim([-300,400])
ax1.set_zlim([-300,400])
plt.show()
